# %% [markdown]
# <a href="https://colab.research.google.com/github/sha-doow/ML/blob/main/NN_on_Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
from google.colab import files
import pandas as pd

# Upload the dataset file from your local machine
uploaded = files.upload()
# Out:
#      <input type="file" id="files-91cc7b02-08d0-4658-98c3-5c246d5c1d44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91cc7b02-08d0-4658-98c3-5c246d5c1d44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# load the dataset, split into input (X) and output (y) variables
dataset = np.loadtxt('diabetes.csv', delimiter=',', skiprows=1)
X = dataset[:,0:8]
y = dataset[:,8]

# %%
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)
# Out:
# <ipython-input-17-1b22176d8fdd>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X = torch.tensor(X, dtype=torch.float32)
# <ipython-input-17-1b22176d8fdd>:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)

# %%
model = nn.Sequential(
    nn.Linear(8, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid()

)

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=8, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
n_epochs = 100
batch_size = 10

for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i+batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i+batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.7999703884124756
# Finished epoch 1, latest loss 0.7354319095611572
# Finished epoch 2, latest loss 0.6498773097991943
# Finished epoch 3, latest loss 0.5874055624008179
# Finished epoch 4, latest loss 0.5450512766838074
# Finished epoch 5, latest loss 0.5163742899894714
# Finished epoch 6, latest loss 0.4987010359764099
# Finished epoch 7, latest loss 0.4902372360229492
# Finished epoch 8, latest loss 0.4776180684566498
# Finished epoch 9, latest loss 0.46968668699264526
# Finished epoch 10, latest loss 0.4608888328075409
# Finished epoch 11, latest loss 0.4581793248653412
# Finished epoch 12, latest loss 0.4583466053009033
# Finished epoch 13, latest loss 0.4563535749912262
# Finished epoch 14, latest loss 0.4612905979156494
# Finished epoch 15, latest loss 0.4557608366012573
# Finished epoch 16, latest loss 0.4460177421569824
# Finished epoch 17, latest loss 0.43090352416038513
# Finished epoch 18, latest loss 0.4527333378791809
# ...

# %%
# compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)

accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.765625
